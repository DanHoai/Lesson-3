# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.9/272.9 KB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 41.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 KB 3.6 MB/s eta 0:00:00
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11959 sha256=f65f29834270cd62dd251dbbc3dcfd92bb3de888de9433058acdd41509eadd4b
#   Stored in directory: /root/.cache/pip/wheels/dc/b9/4a/948b1176e084b9e3f85e4ffc3d08f817b1fdf0d973bbb94f81
# ...

# %%
# !scrapy startproject tiki
# Out:
# New Scrapy project 'tiki', using template directory '/usr/local/lib/python3.8/dist-packages/scrapy/templates/project', created in:
#     /content/tiki
#
# You can start your first spider with:
#     cd tiki
#     scrapy genspider example example.com

# %%
# %cd tiki
# Out:
# /content/tiki

# %%
# !scrapy genspider tikis tiki.vn
# Out:
# Created spider 'tikis' using template 'basic' in module:
#   tiki.spiders.tikis

# %%
# %cd /content/drive/MyDrive/SINH VIÊN 2023/UEH/Machine Learning/Buổi 3/tiki/tiki/spiders
# Out:
# /content/drive/MyDrive/SINH VIÊN 2023/UEH/Machine Learning/Buổi 3/tiki/tiki/spiders

# %%
# !scrapy crawl tikis -o tiki_products.json
# Out:
# 2023-02-08 05:04:44 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: tiki)
# 2023-02-08 05:04:44 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.8.10 (default, Nov 14 2022, 12:59:47) - [GCC 9.4.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.1, Platform Linux-5.10.147+-x86_64-with-glibc2.29
# 2023-02-08 05:04:44 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'tiki',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'tiki.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['tiki.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
# 2023-02-08 05:04:44 [asyncio] DEBUG: Using selector: EpollSelector
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
